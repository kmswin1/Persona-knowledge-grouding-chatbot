# %%
import json
import numpy as np

# %%
lens=[]
for line in train:
    print (line.keys())
    print (line['triples'][0])
    break
# Out:
# dict_keys(['dialogID', 'persona', 'landmark_link', 'knowledge', 'utterance', 'triples'])
# {'subject': 'Roman Catholic Diocese', 'relation': 'is', 'object': 'church'}

# %%
lens=[]
for line in train:
    lens.append(len(line['triples']))

# %%
rels = set()
for line in train:
    for t in line['triples']:
        rels.add(t['relation'])

# %%
len(rels), rels
# Out:
# (503311,
#  {'was effectively isolated from',
#   'replaced several months later',
#   'boasted about',
#   'was cleaned out In',
#   'opened building In',
#   'depowered Doom',
#   'also sitting as',
#   'However lost to',
#   'theatres than',
#   'bought Richmond Lodge In',
#   'instead push',
#   'however had again expelled',
#   'finally opened Flamingo Hotel on',
#   'was officially renamed National Library In',
#   'was summoned before',
#   'experienced reversal with',
#   'would limit to',
#   'is filled from',
#   'forms rectangle as',
#   'of plains is',
#   'bought around',
#   'was independent kingdom with',
#   'was performed following',
#   'however crumbled During',
#   'refuse from',
#   'ascended Theodul Pass in',
#   'busied',
#   'extends upward toward',
#   'came as early to',
#   'relocated As',
#   'declined rapidly from',
#   'also gather',
#   'Singers of',
#   'circumscribes Red House Lake In',
#   'forcefully relocating Japanese Americans from',
# ...

# %%
with open('data/new_valid_json.json', 'r') as f:
    valid = json.load(f)

# %%
print(len(valid))
for line in valid:
    print (line.keys())
    print(line)
    break
# Out:
# 1000
# dict_keys(['dialogID', 'persona', 'landmark_link', 'knowledge', 'utterance', 'triples'])
# ...

# %%
rels = set()
for line in valid:
    for t in line['triples']:
        rels.add(t['relation'])

# %%
len(rels), rels
# Out:
# (121467,
#  {'signalled reception with',
#   'Above made impression in',
#   'form rubble field Since',
#   'was appearance in',
#   'will remind',
#   'Formerly was split Skull Island into',
#   'stumbled on',
#   'ceremony for',
#   'labeled as',
#   'was rented out by',
#   'is registered by',
#   'refers according',
#   'were also made from',
#   'was suffering from',
#   'sheathed with',
#   'was designated city landmark In',
#   'was given authority In',
#   'was indeed dedicated to',
#   'were scrapped at_time',
#   'was always restricted by',
#   'being canceled in',
#   'will take through',
#   'distance between',
#   'ordered because',
#   'shape of',
#   'potential American attack from',
#   'has happened quite rapidly On',
#   'granted church In',
#   'took clients until',
#   'ranks second In',
#   'Further helped with',
#   'recently have become during',
#   'purchase at',
#   'crushed utterly so far',
#   'block of is',
#   'Ranging from',
#   'Completing',
# ...

# %%
lens=[]
for line in data:
    lens.append(len(line['triples']))

# %%
np.mean(lens)
# Out:
# 1297.841

# %%
with open('new_train_json.json', 'r') as f:
    train = json.load(f)

# %%
lens=[]
for line in train:
    lens.append(len(line['triples']))

# %%
np.mean(lens)

# %%
rels = set()
for line in train:
    for t in line['triples']:
        rels.add(t['relation'])

# %%
len(train)
